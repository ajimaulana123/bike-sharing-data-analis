# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - Nama: Aji Maualana
# - Email: ajimaulana094@gmail.com
# - Id Dicoding: ajimaulana07

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pada jam berapa penyewaan sepeda paling banyak dan paling sedikit terjadi?
# - Pada musim apa penyewaan sepeda paling banyak?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# ### Hour

# %%
#Load file hour.csv
hour_df = pd.read_csv("data/hour.csv")
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Day

# %%
#Load file day.csv
day_df = pd.read_csv("data/day.csv")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# **Insight:**
# - File hour.csv berisi data mengenai jumlah penyewaan sepeda setiap jamnya. Data ini seperti tanggal, musim, hari dalam seminggu, kondisi cuaca, suhu, kelembaban, kecepatan angin, dan jumlah pengguna, baik yang terdaftar maupun yang tidak.
# - File day.csv berisi data kumpulan jumlah penyewaan sepeda per hari. Data ini berisi informasi yang serupa dengan hour.csv, namun dengan tingkat kumpulan informasi yang lebih umum. Dengan data harian, saya dapat melihat tren penggunaan sepeda dalam jangka waktu yang lebih panjang, seperti berdasarkan musiman, pengaruh hari libur, atau dampak dari hari hari tertentu seperti hari kerja atau libur terhadap jumlah penyewaan sepeda.

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# ### Hour

# %%
# memeriksa tipe data data dari tiap kolom
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
# Periksa apakah ada duplikasi data
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
# Periksa apakah ada missing value
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# Menampilkan ringkasan parameter statistik
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ### Day

# %%
# memeriksa tipe data data dari tiap kolom
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
# Periksa apakah ada duplikasi data
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
# Periksa apakah ada missing value
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# Menampilkan ringkasan parameter statistik
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# **Insight:**
#
# Kualitas data sudah baik, tanpa anomali, missing value, duplikat, atau nilai yang tidak akurat. Namun, ada beberapa perbaikan yang perlu dilakukan. Pertama, kolom instant yang tidak relevan di day_df ( untuk hour digunakan pada RFM analisis ) dan kolom workingday yang sudah diwakili oleh weekday akan dihapus. Selanjutnya, kolom season, mnth, holiday, weekday, dan weathersit akan diubah dari tipe int menjadi category karena seharusnya berupa data kategorikal. Kolom dteday juga akan diubah dari object menjadi datetime untuk mempermudah analisis. Nama-nama kolom akan diganti agar lebih mudah dibaca, dan isi kolom akan dikonversi agar lebih mudah dipahami. Terakhir, kolom baru bernama category_days akan ditambahkan untuk menunjukkan apakah hari tersebut adalah weekend atau weekday.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Dropping

# %%
# Hapus kolom instant dan workingday pada hour.
hour_df.drop(["workingday"], axis = 1, inplace= True)

# Hapus kolom instant dan workingday pada day.
day_df.drop(["workingday"], axis = 1, inplace= True)
day_df.drop(["instant"], axis = 1, inplace= True)

# %% [markdown]
# #### Konversi Tipe Data

# %%
# Ubah tipe data numerik ke categori
columns = ["season", "mnth", "holiday", "weekday", "weathersit"]
 
for column in columns:
    day_df[column] =  day_df[column].astype("category")
    
    hour_df[column] =  hour_df[column].astype("category")

# %%
# ubah tipe data object ke datetime
day_df["dteday"] = pd.to_datetime(day_df["dteday"])

hour_df["dteday"] = pd.to_datetime(hour_df["dteday"])

# %% [markdown]
# #### Rename

# %%
# ubah nama kolom di day_df
day_df.rename(columns={
    "yr": "year",
    "mnth": "month",
    "weekday": "one_of_week",
    "weathersit": "weather_situation",
    "windspeed": "wind_speed",
    "cnt": "count",
    "hum": "humidity"
}, inplace=True)

# %%
#  ubah nama kolom di hour_df
hour_df.rename(columns={
    "yr": "year",
    "hr": "hours",
    "mnth": "month",
    "weekday": "one_of_week",
    "weathersit": "weather_situation",
    "windspeed": "wind_speed",
    "cnt": "count",
    "hum": "humidity"
}, inplace=True)

# %%
# Fungsi untuk mengganti nilai dalam kolom DataFrame
def replace_values(df, column, replacements):
    """Mengganti nilai dalam kolom DataFrame."""
    df[column] = df[column].replace(replacements)

# Konversi season
season_mapping = {1: "Spring", 2: "Summer", 3: "Fall", 4: "Winter"}
replace_values(day_df, 'season', season_mapping)
replace_values(hour_df, 'season', season_mapping)

# Konversi month
month_mapping = {
    1: "Jan", 2: "Feb", 3: "Mar", 4: "Apr", 5: "May",
    6: "Jun", 7: "Jul", 8: "Aug", 9: "Sep", 10: "Oct",
    11: "Nov", 12: "Dec"
}
replace_values(day_df, 'month', month_mapping)
replace_values(hour_df, 'month', month_mapping)

# Konversi weather_situation
weather_mapping = {1: "Clear", 2: "Misty", 3: "Light_RainSnow", 4: "Heavy_RainSnow"}
replace_values(day_df, 'weather_situation', weather_mapping)
replace_values(hour_df, 'weather_situation', weather_mapping)

# Konversi one_of_week
week_mapping = {
    0: "Sunday", 1: "Monday", 2: "Tuesday", 
    3: "Wednesday", 4: "Thursday", 5: "Friday", 6: "Saturday"
}
replace_values(day_df, 'one_of_week', week_mapping)
replace_values(hour_df, 'one_of_week', week_mapping)

# Konversi year
year_mapping = {0: "2011", 1: "2012"}
replace_values(day_df, 'year', year_mapping)
replace_values(hour_df, 'year', year_mapping)

# Menghitung Humidity
day_df['humidity'] = day_df['humidity'] * 100
hour_df['humidity'] = hour_df['humidity'] * 100
# Out:
# /tmp/ipykernel_60558/816707543.py:4: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df[column] = df[column].replace(replacements)
# /tmp/ipykernel_60558/816707543.py:4: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df[column] = df[column].replace(replacements)
# /tmp/ipykernel_60558/816707543.py:4: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
# ...

# %% [markdown]
# #### Membuat kolom baru bernama category_days

# %%
# Membuat kolom baru bernama category_days
def get_category_days(day):
    return "weekend" if day in ["Saturday", "Sunday"] else "weekdays"

# Gunakan fungsi untuk membuat kolom category_days
hour_df["category_days"] = hour_df["one_of_week"].apply(get_category_days)
day_df["category_days"] = day_df["one_of_week"].apply(get_category_days)

# %%
def classify_humidity(humidity):
    if humidity < 45:
        return "Terlalu kering"
    elif 45 <= humidity < 65:
        return "Ideal"
    return "Terlalu lembab"

# Terapkan fungsi untuk membuat kolom humidity_category
hour_df["humidity_category"] = hour_df["humidity"].apply(classify_humidity)
day_df["humidity_category"] = day_df["humidity"].apply(classify_humidity)

# %% [markdown]
# **Insight:**
#
# Perbaikan telah diselesaikan sehingga, kolom instant dan workingday telah dihapus. Selanjutnya, kolom season, mnth, holiday, weekday, dan weathersit telah diubah dari tipe int menjadi category, kolom dteday telah diubah dari object menjadi datetime, kolom baru bernama category_days akan ditambahkan untuk kalsifikasi hari.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Hour

# %%
# melihat rangkuman parameter statistik dari data hour_df 
hour_df.describe(include="all")
# Out:
#            instant                         dteday season   year  month  \
# count   17379.0000                          17379  17379  17379  17379
# unique         NaN                            NaN      4      2     12
# top            NaN                            NaN   Fall   2012    May
# freq           NaN                            NaN   4496   8734   1488
# mean     8690.0000  2012-01-02 04:08:34.552045568    NaN    NaN    NaN
# min         1.0000            2011-01-01 00:00:00    NaN    NaN    NaN
# 25%      4345.5000            2011-07-04 00:00:00    NaN    NaN    NaN
# 50%      8690.0000            2012-01-02 00:00:00    NaN    NaN    NaN
# 75%     13034.5000            2012-07-02 00:00:00    NaN    NaN    NaN
# max     17379.0000            2012-12-31 00:00:00    NaN    NaN    NaN
# std      5017.0295                            NaN    NaN    NaN    NaN
#
#                hours  holiday one_of_week weather_situation          temp  \
# ...

# %%
# Agregasi sewa berdasarkan jam
hourly_counts = hour_df.groupby(by="hours").agg({"count": "sum"})

# Mengubah format angka dengan titik sebagai pemisah ribuan
hourly_counts['count'] = hourly_counts['count'].apply(lambda x: f"{int(x):,}".replace(",", "."))

# Menampilkan hasil
print(hourly_counts)
# Out:
#          count
# hours
# 0       39.130
# 1       24.164
# 2       16.352
# 3        8.174
# 4        4.428
# 5       14.261
# 6       55.132
# 7      154.171
# 8      261.001
# 9      159.438
# 10     126.257
# 11     151.320
# 12     184.414
# 13     184.919
# 14     175.652
# 15     183.149
# 16     227.748
# 17     336.860
# 18     309.772
# 19     226.789
# 20     164.550
# 21     125.445
# 22      95.612
# 23      63.941

# %% [markdown]
# ### Day

# %%
# melihat rangkuman parameter statistik dari data day_df 
day_df.describe(include="all")
# Out:
#                      dteday season  year month  holiday one_of_week  \
# count                   731    731   731   731    731.0         731
# unique                  NaN      4     2    12      2.0           7
# top                     NaN   Fall  2012   Jan      0.0      Sunday
# freq                    NaN    188   366    62    710.0         105
# mean    2012-01-01 00:00:00    NaN   NaN   NaN      NaN         NaN
# min     2011-01-01 00:00:00    NaN   NaN   NaN      NaN         NaN
# 25%     2011-07-02 12:00:00    NaN   NaN   NaN      NaN         NaN
# 50%     2012-01-01 00:00:00    NaN   NaN   NaN      NaN         NaN
# 75%     2012-07-01 12:00:00    NaN   NaN   NaN      NaN         NaN
# max     2012-12-31 00:00:00    NaN   NaN   NaN      NaN         NaN
# std                     NaN    NaN   NaN   NaN      NaN         NaN
#
#        weather_situation        temp       atemp    humidity  wind_speed  \
# count                731  731.000000  731.000000  731.000000  731.000000
# ...

# %%
# Melihat jumlah penyewaan tiap musim
top_seasons = (
    day_df.groupby(by="season", observed=True)["count"]
    .sum()
    .sort_values(ascending=False)
    .reset_index()
    .head(10)
)

# Mengubah format angka dengan titik sebagai pemisah ribuan
top_seasons['count'] = top_seasons['count'].apply(lambda x: f"{int(x):,}".replace(",", "."))

# Menampilkan hasil
print(top_seasons)
# Out:
#    season      count
# 0    Fall  1.061.129
# 1  Summer    918.589
# 2  Winter    841.613
# 3  Spring    471.348

# %% [markdown]
# **Insight:**
#
# Hasil dari eksplorasi data ditemukan terdapat 17.379 pelanggan dengan rata-rata penyewaan sepeda terjadi pada jam 11.54, memiliki standar deviasi sebesar 6.91. Penyewaan terbanyak terjadi pada jam 17.00, sementara jam 04.00 mencatat penyewaan paling sedikit. Dari data ini, saya juga mengatakan bahwa musim fall dan summer merupakan dua musim dengan jumlah penyewaan tertinggi.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
- Pada jam berapa penyewaan sepeda paling banyak dan paling sedikit terjadi?

# %%
# Grouping berdasarkan jam dan menghitung jumlah penyewaan
sum_order_items_df = hour_df.groupby("hours")["count"].sum().sort_values(ascending=False).reset_index()

# %%
# Misalkan sum_order_items_df adalah DataFrame yang sudah ada
# Membuat bar chart untuk melihat perbedaan penyewaan sepeda berdasarkan jam
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(35, 15))

# Membuat barplot untuk penyewa sepeda terbanyak 
sns.barplot(x="hours", y="count", data=sum_order_items_df.head(5), 
            hue="hours", palette=["#D3D3D3", "#D3D3D3", "#FF7F7F", "#D3D3D3", "#D3D3D3"], 
            ax=ax[0], legend=False)

# Mengatur label dan judul untuk subplot pertama
ax[0].set_ylabel(None)
ax[0].set_xlabel("Hours (PM)", fontsize=30)
ax[0].set_title("Jam dengan banyak penyewa sepeda", loc="center", fontsize=30)
ax[0].tick_params(axis='y', labelsize=35)
ax[0].tick_params(axis='x', labelsize=30)

# Membuat barplot untuk penyewa sepeda terdikit 
sns.barplot(x="hours", y="count", data=sum_order_items_df.sort_values(by="count", ascending=True).head(5), 
            hue="hours", palette=["#D3D3D3", "#D3D3D3", "#D3D3D3", "#90CAF9", "#D3D3D3"], 
            ax=ax[1], legend=False)

# Mengatur label dan judul untuk subplot kedua
ax[1].set_ylabel(None)
ax[1].set_xlabel("Hours (AM)", fontsize=30)
ax[1].set_title("Jam dengan sedikit penyewa sepeda", loc="center", fontsize=30)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].tick_params(axis='y', labelsize=35)
ax[1].tick_params(axis='x', labelsize=30)

# Menampilkan plot
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
- Pada musim apa penyewaan sepeda paling banyak?

# %%
from matplotlib.ticker import FuncFormatter

# Misalkan day_df adalah DataFrame yang sudah ada
# Mengatur warna
colors = ["#D3D3D3", "#D3D3D3", "#FF7F7F", "#D3D3D3"]

# Membuat subplot dengan ukuran (20, 10)
fig, ax = plt.subplots(figsize=(20, 10))

# Menghitung jumlah penyewaan per musim
top_seasons = (
    day_df.groupby(by="season", observed=True)["count"]
    .sum()
    .sort_values(ascending=False)
    .reset_index()
    .head(10)
)

# Buat barplot untuk y="count" dan x="season"
sns.barplot(
    x="season",
    y="count",
    data=top_seasons,  # Menggunakan data yang sudah diolah
    ax=ax,
    palette=colors,
    hue="season",  # Menetapkan hue ke "season" untuk menghindari peringatan
    dodge=False,   # Agar bar tidak terpisah
    legend=False   # Menghilangkan legend
)

# Mengatur format sumbu y untuk menampilkan angka dalam ribu dan juta
def format_func(value, tick_number):
    if value >= 1_000_000:
        return f'{value / 1_000_000:.1f} juta'
    elif value >= 1_000:
        return f'{value / 1_000:.0f} ribu'
    else:
        return int(value)

ax.yaxis.set_major_formatter(FuncFormatter(format_func))

# Mengatur judul, label y dan x, serta tick params untuk subplot tersebut
ax.set_title("Grafik Antar Musim", loc="center", fontsize=50)
ax.set_ylabel(None)
ax.set_xlabel(None)
ax.tick_params(axis='x', labelsize=35)
ax.tick_params(axis='y', labelsize=30)

# Menampilkan plot
plt.show()

# %% [markdown]
# **Insight:**
#
# Penyewaan sepeda paling ramai terjadi pada jam 17:00 dengan sekitar 336.860 penyewaan, sedangkan pada jam 04:00 jumlahnya jauh lebih sedikit, hanya sekitar 4.428 penyewaan. Selain itu, musim yang paling banyak menyewa sepeda adalah Fall (musim gugur), dengan total mencapai 1.061.129 penyewaan.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ### 1. Analisis Clustering

# %% [markdown]
# #### Total Pengguna Berdasarkan weather_situation

# %%
# Menghitung jumlah nilai unik untuk setiap kolom berdasarkan situasi cuaca
weather_counts = hour_df.groupby(by="weather_situation", observed=True).nunique()

# Mengurutkan hasil berdasarkan jumlah unik dan menampilkannya
sorted_weather_counts = weather_counts.sort_values(by='count', ascending=False)

# Menampilkan hasil
print(sorted_weather_counts)
# Out:
#                    instant  dteday  season  year  month  hours  holiday  \
# weather_situation
# Clear                11413     700       4     2     12     24        2
# Misty                 4544     567       4     2     12     24        2
# Light_RainSnow        1419     300       4     2     12     24        2
# Heavy_RainSnow           3       3       1     2      1      3        1
#
#                    one_of_week  temp  atemp  humidity  wind_speed  casual  \
# weather_situation
# Clear                        7    50     65        84          28     315
# Misty                        7    47     59        78          25     219
# Light_RainSnow               7    40     49        57          25     121
# Heavy_RainSnow               3     3      3         2           3       2
#
#                    registered  count  category_days  humidity_category
# weather_situation
# Clear                     744    848              2                  3
# ...

# %% [markdown]
# **Insight:**
#
# Penyewaan tertinggi terjadi saat cuaca Clear dengan 848 sepeda, Misty dengan 649 penyewaan. kemudian, cuaca Light Rain/Snow hanya mencatat 368 penyewaan, dan Heavy Rain/Snow sangat sedikit dengan 3 sepeda.

# %% [markdown]
# #### Total Pengguna Berdasarkan Humidity

# %%
hour_df.groupby(by="humidity_category").agg({"count": ["count"]})
# Out:
#                   count
#                   count
# humidity_category
# Ideal              5505
# Terlalu kering     3518
# Terlalu lembab     8356

# %% [markdown]
# **Insight:**
#
# Kelembapan yang lebih tinggi membuat orang untuk menyewa sepeda lebih banyak.

# %% [markdown]
# ### 2. RFM Analysis

# %%
current_date = max(hour_df['dteday'])
rfm_df = hour_df.groupby('registered').agg({
    'dteday': lambda x: (current_date - x.max()).days,  # Recency
    'instant': 'count',  # Frequency
    'count': 'sum'  # Monetary
}).reset_index()

# Rename nama
rfm_df.columns = ['registered', 'Recency', 'Frequency', 'Monetary']

print(rfm_df.head())
# Out:
#    registered  Recency  Frequency  Monetary
# 0           0       38         24        35
# 1           1        0        201       294
# 2           2        1        245       648
# 3           3        0        294      1154
# 4           4        3        307      1602

# %% [markdown]
# **Insight:**
#
# Pengguna yang lebih aktif cenderung menyewa sepeda lebih sering dan menghabiskan lebih banyak uang. Sebaliknya, pengguna dengan nilai Recency yang tinggi mungkin perlu didorong agar kembali menyewa sepeda.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Di temukan bahwa terdapat 17.379 pelanggan dengan rata-rata penyewaan sepeda terjadi pada jam 11:54, memiliki standar deviasi sebesar 6,91. Penyewaan sepeda paling ramai terjadi pada jam 17:00, dengan total sekitar 336.860 penyewaan, sementara jam 04:00 mencatat jumlah penyewaan paling sedikit, hanya sekitar 4.428. Dari analisis ini, saya juga mengamati bahwa musim Fall dan Summer adalah dua musim dengan jumlah penyewaan tertinggi, di mana musim Fall mencapai total penyewaan 1.061.129. Di sisi lain udara lembab dan cuaca cerah lebih banyak membuat orang untuk menyewa sepeda. Pengguna yang lebih aktif cenderung menyewa sepeda lebih sering dan menghabiskan lebih banyak uang. Sebaliknya, pengguna dengan nilai Recency yang tinggi mungkin perlu didorong agar kembali menyewa sepeda.
